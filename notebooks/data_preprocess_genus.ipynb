# %% [markdown]
# # <center>Collection Formation with Genuses</center>
# ## <center>Second Approach to collection formation</center>

# %%
import pandas as pd

# %%
df = pd.read_csv('plantCLFdataset-train.csv')
df.shape
# Out:
# (91758, 6)

# %%
df.head()
# Out:
#     FileName  ObservationId   Content           Family       Genus  \
# 0  46826.xml           7354    Flower  Caryophyllaceae    Myosoton
# 1   5848.xml           5554    Flower         Linaceae       Linum
# 2  78710.xml          12084    Entire   Plantaginaceae  Globularia
# 3  31476.xml          25185  LeafScan       Betulaceae    Carpinus
# 4  68503.xml           9663    Flower      Orchidaceae      Ophrys
#
#                           Species
# 0  Myosoton aquaticum (L.) Moench
# 1          Linum usitatissimum L.
# 2            Globularia alypum L.
# 3             Carpinus betulus L.
# 4          Ophrys aranifera Huds.

# %% [markdown]
# ## Filter Leaf and Flower from the dataset

# %%
df_LeafandFlower = df[df.Content.isin(['Flower','Leaf','LeafScan'])].reset_index(drop=True)
df_LeafandFlower.shape
# Out:
# (54197, 6)

# %% [markdown]
# ## Create collection with one Leaf and one Flower

# %%
collection_dict = {}
for key in df_LeafandFlower.index:
    collection_dict[key] = 0

# %%
collection_counter = 0
for genus in df_LeafandFlower.Genus.unique():
    df_genus = df_LeafandFlower[df_LeafandFlower.Genus == genus]
    flower_df = df_genus[df_genus.Content == "Flower"]
    leaf_df = df_genus[~df_genus.index.isin(flower_df.index)]
    cut_off = flower_df.shape[0] if flower_df.shape[0] <= leaf_df.shape[0] else leaf_df.shape[0]
    if cut_off != 0:
        flower_df_sel_index = flower_df.sample(n=cut_off).index
        leaf_df_sel_index = leaf_df.sample(n=cut_off).index
        for i in range(cut_off):
            collection_counter += 1
            collection_dict[flower_df_sel_index[i]] = collection_counter
            collection_dict[leaf_df_sel_index[i]] = collection_counter

# %%
df_LeafandFlower['index'] = df_LeafandFlower.index
df_LeafandFlower
# Out:
#         FileName  ObservationId   Content           Family     Genus  \
# 0      46826.xml           7354    Flower  Caryophyllaceae  Myosoton
# 1       5848.xml           5554    Flower         Linaceae     Linum
# 2      31476.xml          25185  LeafScan       Betulaceae  Carpinus
# 3      68503.xml           9663    Flower      Orchidaceae    Ophrys
# 4      59906.xml          14317      Leaf         Fagaceae   Quercus
# ...          ...            ...       ...              ...       ...
# 54192  78709.xml           3850    Flower       Asteraceae  Berardia
# 54193   5851.xml          41224      Leaf    Anacardiaceae  Pistacia
# 54194  40296.xml          30438    Flower      Orchidaceae   Neottia
# 54195  36300.xml           9076  LeafScan       Betulaceae    Betula
# 54196  70355.xml           2062    Flower      Sapindaceae      Acer
#
#                                 Species  index
# 0        Myosoton aquaticum (L.) Moench      0
# 1                Linum usitatissimum L.      1
# 2                   Carpinus betulus L.      2
# 3                Ophrys aranifera Huds.      3
# 4                      Quercus suber L.      4
# ...                                 ...    ...
# 54192  Berardia lanuginosa (Lam.) Fiori  54192
# 54193             Pistacia lentiscus L.  54193
# 54194     Neottia nidus-avis (L.) Rich.  54194
# 54195               Betula pendula Roth  54195
# 54196                 Acer opalus Mill.  54196
#
# [54197 rows x 7 columns]

# %%
df_LeafandFlower['CollectionId'] = df_LeafandFlower['index'].map(collection_dict)
df_LeafandFlower
# Out:
#         FileName  ObservationId   Content           Family     Genus  \
# 0      46826.xml           7354    Flower  Caryophyllaceae  Myosoton
# 1       5848.xml           5554    Flower         Linaceae     Linum
# 2      31476.xml          25185  LeafScan       Betulaceae  Carpinus
# 3      68503.xml           9663    Flower      Orchidaceae    Ophrys
# 4      59906.xml          14317      Leaf         Fagaceae   Quercus
# ...          ...            ...       ...              ...       ...
# 54192  78709.xml           3850    Flower       Asteraceae  Berardia
# 54193   5851.xml          41224      Leaf    Anacardiaceae  Pistacia
# 54194  40296.xml          30438    Flower      Orchidaceae   Neottia
# 54195  36300.xml           9076  LeafScan       Betulaceae    Betula
# 54196  70355.xml           2062    Flower      Sapindaceae      Acer
#
#                                 Species  index  CollectionId
# 0        Myosoton aquaticum (L.) Moench      0             3
# 1                Linum usitatissimum L.      1             0
# 2                   Carpinus betulus L.      2            10
# 3                Ophrys aranifera Huds.      3             0
# 4                      Quercus suber L.      4             0
# ...                                 ...    ...           ...
# 54192  Berardia lanuginosa (Lam.) Fiori  54192         10957
# 54193             Pistacia lentiscus L.  54193             0
# 54194     Neottia nidus-avis (L.) Rich.  54194             0
# 54195               Betula pendula Roth  54195             0
# 54196                 Acer opalus Mill.  54196           642
#
# [54197 rows x 8 columns]

# %% [markdown]
# ## Filter out unused images

# %%
df_collection = df_LeafandFlower[df_LeafandFlower.CollectionId != 0]
df_collection = df_collection.drop(['index'],axis=1)
df_collection
# Out:
#          FileName  ObservationId   Content           Family        Genus  \
# 0       46826.xml           7354    Flower  Caryophyllaceae     Myosoton
# 2       31476.xml          25185  LeafScan       Betulaceae     Carpinus
# 7       37007.xml          18801    Flower   Convolvulaceae  Convolvulus
# 10      51382.xml          29563  LeafScan      Platanaceae     Platanus
# 11     105943.xml          22639    Flower         Fagaceae      Quercus
# ...           ...            ...       ...              ...          ...
# 54186   66537.xml          16787    Flower       Asteraceae       Bidens
# 54189   48812.xml          12306    Flower         Fabaceae     Medicago
# 54190   76724.xml          27033    Flower        Cornaceae       Cornus
# 54192   78709.xml           3850    Flower       Asteraceae     Berardia
# 54196   70355.xml           2062    Flower      Sapindaceae         Acer
#
#                                      Species  CollectionId
# 0             Myosoton aquaticum (L.) Moench             3
# 2                        Carpinus betulus L.            10
# 7                    Convolvulus arvensis L.           242
# 10     Platanus x hispanica Mill. ex Münchh.           419
# 11                      Quercus coccifera L.           107
# ...                                      ...           ...
# 54186                       Bidens pilosa L.         10398
# 54189                     Medicago sativa L.          8500
# 54190                          Cornus mas L.          4813
# 54192       Berardia lanuginosa (Lam.) Fiori         10957
# 54196                      Acer opalus Mill.           642
#
# [22186 rows x 7 columns]

# %%
df_collection.CollectionId.value_counts()
# Out:
# 2049     2
# 1322     2
# 9486     2
# 5400     2
# 7449     2
#         ..
# 613      2
# 6758     2
# 4711     2
# 10864    2
# 2047     2
# Name: CollectionId, Length: 11093, dtype: int64

# %% [markdown]
# ## Filter out Genuses with less than 20 collections(40 images)

# %%
df_collection_filtered = df_collection.copy()
for genus in df_collection.Genus.unique():
    df_genus = df_collection[df_collection.Genus == genus]
    if df_genus.shape[0] < 40:
        df_collection_filtered = df_collection_filtered.drop(df_genus.index)
print(df_collection_filtered.shape)
# Out:
# (17338, 7)

# %%
df_collection_filtered.Genus.value_counts()
# Out:
# Prunus        764
# Euphorbia     622
# Geranium      470
# Acer          464
# Crataegus     366
#              ...
# Orchis         40
# Reynoutria     40
# Anthriscus     40
# Oenothera      40
# Knautia        40
# Name: Genus, Length: 158, dtype: int64

# %%
df_collection_filtered[df_collection_filtered.CollectionId==10]
# Out:
#          FileName  ObservationId   Content      Family     Genus  \
# 2       31476.xml          25185  LeafScan  Betulaceae  Carpinus
# 53830  100177.xml           2476    Flower  Betulaceae  Carpinus
#
#                    Species  CollectionId
# 2      Carpinus betulus L.            10
# 53830  Carpinus betulus L.            10

# %%
df_collection.to_csv("plantCLFcollection_genus.csv",index=False)
