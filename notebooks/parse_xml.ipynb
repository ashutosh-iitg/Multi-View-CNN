# %% [markdown]
# # <center>Parse XML files of PlantCLEF Dataset</center>

# %%
import os
import pandas as pd
import xml.etree.ElementTree as ET
from tqdm.notebook import tqdm

# %%
file_list = os.listdir("train-xml")
print("No. of XML files to process:", len(file_list))
# Out:
# No. of XML files to process: 91758

# %%
file_list[0]
# Out:
# '46826.xml'

# %%
tree = ET.parse(os.path.join("train-xml",file_list[0]))
root = tree.getroot()
for child in root:
    print(child.tag,": ",child.text)
# Out:
# ObservationId :  7354
# MediaId :  46826
# Vote :  2.5
# Content :  Flower
# ClassId :  2140
# Family :  Caryophyllaceae
# Genus :  Myosoton
# Species :  Myosoton aquaticum (L.) Moench
# Author :  emmanuel stratmains
# Date :  2012-8-1
# Location :  Allonnes
# Latitude :  47.97051
# Longitude :  0.16968
# YearInCLEF :  PlantCLEF2015
# ObservationId2014 :  None
# ImageId2014 :  None
# LearnTag :  Train

# %%
print([item.tag for item in root])
# Out:
# ['ObservationId', 'MediaId', 'Vote', 'Content', 'ClassId', 'Family', 'Genus', 'Species', 'Author', 'Date', 'Location', 'Latitude', 'Longitude', 'YearInCLEF', 'ObservationId2014', 'ImageId2014', 'LearnTag']

# %% [markdown]
# ## Adding all the relevant infromation to dataframe

# %%
df = pd.DataFrame(columns = ["FileName","ObservationId","Content","Family","Genus","Species"])

for file in tqdm(file_list):
    tree = ET.parse(os.path.join("train-xml",file))
    root = tree.getroot()

    info_dict = {}
    info_dict['FileName'] = file
    for child in root:
        if child.tag == "ObservationId":
            info_dict['ObservationId'] = child.text
        if child.tag == "Content":
            info_dict['Content'] = child.text
        if child.tag == "Family":
            info_dict['Family'] = child.text
        if child.tag == "Genus":
            info_dict['Genus'] = child.text
        if child.tag == "Species":
            info_dict['Species'] = child.text
    df = df.append(info_dict,ignore_index=True)
# Out:
#   0%|          | 0/91758 [00:00<?, ?it/s]

# %%
df.head(20)
# Out:
#       FileName ObservationId   Content           Family        Genus  \
# 0    46826.xml          7354    Flower  Caryophyllaceae     Myosoton
# 1     5848.xml          5554    Flower         Linaceae        Linum
# 2    78710.xml         12084    Entire   Plantaginaceae   Globularia
# 3    31476.xml         25185  LeafScan       Betulaceae     Carpinus
# 4    68503.xml          9663    Flower      Orchidaceae       Ophrys
# 5    21665.xml         18122     Fruit    Ranunculaceae      Anemone
# 6    59906.xml         14317      Leaf         Fagaceae      Quercus
# 7   104485.xml         19800  LeafScan         Fagaceae      Quercus
# 8    71052.xml          4017    Entire          Poaceae    Ammophila
# 9     5690.xml          3021    Flower       Asteraceae        Inula
# 10   37007.xml         18801    Flower   Convolvulaceae  Convolvulus
# 11   38334.xml         40078      Leaf       Salicaceae      Populus
# 12   94960.xml         15710  LeafScan         Fabaceae      Robinia
# 13   51382.xml         29563  LeafScan      Platanaceae     Platanus
# 14   27214.xml         24509    Entire         Pinaceae        Pinus
# 15  105943.xml         22639    Flower         Fagaceae      Quercus
# 16   41191.xml          6576    Flower        Lamiaceae       Lamium
# 17   30768.xml          5453  LeafScan      Sapindaceae         Acer
# 18   75234.xml         11234      Stem     Celastraceae     Euonymus
# 19     162.xml         21176    Entire        Lamiaceae  Clinopodium
#
#                                   Species
# 0          Myosoton aquaticum (L.) Moench
# 1                  Linum usitatissimum L.
# 2                    Globularia alypum L.
# 3                     Carpinus betulus L.
# 4                  Ophrys aranifera Huds.
# 5                     Anemone vernalis L.
# 6                        Quercus suber L.
# 7                  Quercus petraea Liebl.
# 8            Ammophila arenaria (L.) Link
# 9                        Inula conyza DC.
# 10                Convolvulus arvensis L.
# 11                       Populus nigra L.
# 12                Robinia pseudoacacia L.
# 13  Platanus x hispanica Mill. ex Münchh.
# 14                        Pinus cembra L.
# 15                   Quercus coccifera L.
# 16               Lamium maculatum (L.) L.
# 17                 Acer monspessulanum L.
# 18         Euonymus latifolius (L.) Mill.
# 19         Clinopodium nepeta (L.) Kuntze

# %%
df.to_csv("plantCLFdataset-train.csv",index=False)

# %%
df.info
# Out:
# <bound method DataFrame.info of          FileName ObservationId   Content           Family       Genus  \
# 0       46826.xml          7354    Flower  Caryophyllaceae    Myosoton
# 1        5848.xml          5554    Flower         Linaceae       Linum
# 2       78710.xml         12084    Entire   Plantaginaceae  Globularia
# 3       31476.xml         25185  LeafScan       Betulaceae    Carpinus
# 4       68503.xml          9663    Flower      Orchidaceae      Ophrys
# ...           ...           ...       ...              ...         ...
# 91753   36300.xml          9076  LeafScan       Betulaceae      Betula
# 91754   70355.xml          2062    Flower      Sapindaceae        Acer
# 91755  105782.xml          1923     Fruit       Betulaceae       Alnus
# 91756   50085.xml         34245      Stem       Lythraceae     Lythrum
# 91757   39033.xml         38933    Entire     Asparagaceae      Ruscus
#
#                               Species
# 0      Myosoton aquaticum (L.) Moench
# 1              Linum usitatissimum L.
# 2                Globularia alypum L.
# 3                 Carpinus betulus L.
# 4              Ophrys aranifera Huds.
# ...                               ...
# 91753             Betula pendula Roth
# 91754               Acer opalus Mill.
# 91755    Alnus glutinosa (L.) Gaertn.
# 91756            Lythrum salicaria L.
# 91757             Ruscus aculeatus L.
#
# [91758 rows x 6 columns]>

# %%
pd.read_csv("plantCLFdataset-train.csv").head(10)
# Out:
#      FileName  ObservationId   Content           Family       Genus  \
# 0   46826.xml           7354    Flower  Caryophyllaceae    Myosoton
# 1    5848.xml           5554    Flower         Linaceae       Linum
# 2   78710.xml          12084    Entire   Plantaginaceae  Globularia
# 3   31476.xml          25185  LeafScan       Betulaceae    Carpinus
# 4   68503.xml           9663    Flower      Orchidaceae      Ophrys
# 5   21665.xml          18122     Fruit    Ranunculaceae     Anemone
# 6   59906.xml          14317      Leaf         Fagaceae     Quercus
# 7  104485.xml          19800  LeafScan         Fagaceae     Quercus
# 8   71052.xml           4017    Entire          Poaceae   Ammophila
# 9    5690.xml           3021    Flower       Asteraceae       Inula
#
#                           Species
# 0  Myosoton aquaticum (L.) Moench
# 1          Linum usitatissimum L.
# 2            Globularia alypum L.
# 3             Carpinus betulus L.
# 4          Ophrys aranifera Huds.
# 5             Anemone vernalis L.
# 6                Quercus suber L.
# 7          Quercus petraea Liebl.
# 8    Ammophila arenaria (L.) Link
# 9                Inula conyza DC.
